# %%
import pandas as pd

data = pd.read_csv('out.txt', header = None)
data.columns = ["cx", "pwm"]
print(data)
# Out:
#      cx        pwm
# 0    60  37.486155
# 1    58   0.000000
# 2    58  48.535305
# 3    59  48.535305
# 4    59  48.535305
# ..   ..        ...
# 623  74  22.499922
# 624  74  22.499922
# 625  74  22.499922
# 626  74  22.499922
# 627  74  22.499922
#
# [628 rows x 2 columns]

# %%
data.plot(grid=True, kind='line')

# %%
data["pwm"] = data["pwm"].abs()

# %%
data.plot(grid=True, kind='line')

# %%
data["cx"] = 80 - data["cx"]

# %%
data.plot(grid=True, kind='line')
